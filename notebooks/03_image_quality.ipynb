# %% [markdown]
# # 03 — Image-quality features
# Reframe the historical image notebook around transparent metadata and privacy-conscious quality signals.

# %%
examples = [
    {'width': 1200, 'height': 800, 'brightness': 0.72},
    {'width': 640, 'height': 960, 'brightness': 0.31},
]
[(round(x['width']/x['height'], 2), x['brightness']) for x in examples]

# %% [markdown]
# ## Responsible boundary
# Do not infer sensitive attributes or identities. Check media licenses and use aggregate quality indicators only for exploratory product analysis.
