# %% [markdown]
# # Multimodal Restaurant Insights
# Offline exploration of synthetic or properly licensed restaurant reviews and images. No Yelp API key is required.

# %%
import pandas as pd
from restaurant_insights import review_features

reviews = pd.DataFrame({'text': ['Great fresh food', 'Slow service', 'Table near the window']})
reviews.join(reviews['text'].apply(review_features).apply(pd.Series))

# %% [markdown]
# ## Image features
# For locally licensed images, use `image_features(path)` to inspect dimensions, aspect ratio and brightness without uploading media.
